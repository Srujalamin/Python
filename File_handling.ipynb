# %%
file = open("my_text_file.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-1f483a4ff8ec> in <module>
# ----> 1 file = open("my_text_file.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'my_text_file.txt'

# %%
file = open("my_text_file.txt", "w")

# %%
# readable()

file.readable()
# Out:
# False

# %%
# writable()

file.writable()
# Out:
# True

# %%
file.write("Hello, welcome to tops.")
# Out:
# 23

# %%
file.close()

# %%
file = open("my_text_file.txt", "r")

# %%
file.readable()
# Out:
# True

# %%
file.read()
# Out:
# 'Hello, welcome to tops.'

# %%
file.read()
# Out:
# ''

# %%
file.seek(0)
# Out:
# 0

# %%
file.read(5)
# Out:
# 'Hello'

# %%
file.read()
# Out:
# ', welcome to tops.'

# %%
file.tell()
# Out:
# 23

# %%
file.seek(0)
# Out:
# 0

# %%
file.close()

# %%
file = open("my_text_file.txt", "a")

# %%
file.write(" New data.")
# Out:
# 10

# %%
file.close()

# %%
data = ['line one\n', 'line two\n', 'line 3']

# %%
file = open("my_text_file.txt", 'a')

# %%
file.writelines(data)

# %%
file.close()

# %%
file = open("my_text_file.txt", 'r')

# %%
file.readline()
# Out:
# 'Hello, welcome to tops. New data.line one\n'

# %%
file.readline()
# Out:
# 'line two\n'

# %%
file.seek(0)
# Out:
# 0

# %%
file.readlines()
# Out:
# ['Hello, welcome to tops. New data.line one\n', 'line two\n', 'line 3']

# %%
file.close()

# %%
file = open("csv_file.csv", 'w')

# %%
data = "name\tcity\tmobile"
file.write(data)
# Out:
# 16

# %%
file.close()
