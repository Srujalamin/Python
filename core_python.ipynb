# %%
# Out:
#   File "<ipython-input-2-457860706236>", line 2
#     String - str -> single quoted, double quoted, triple quoted/multiline string
#                   ^
# SyntaxError: invalid syntax

# %%
print(city)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7d93cc53d568> in <module>()
# ----> 1 print(city)
#
# NameError: name 'city' is not defined

# %%
city = 'ahmedabad'

# %%
city
# Out:
# 'ahmedabad'

# %%
# print()

print(city)
# Out:
# ahmedabad

# %%
# input()

city = input('enter your city: ')
# Out:
# enter your city: surat

# %%
city
# Out:
# 'surat'

# %%
# type()

type(city)
# Out:
# str

# %%
age = 30

# %%
type(age)
# Out:
# int

# %%
# dir(object)

dir(city)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
'srujal'.__add__(' amin')
# Out:
# 'srujal amin'

# %%
'srujal' + ' amin'

# %%
# capitalize()

city# capitalize()

city
# Out:
# 'surat'

# %%
city.capitalize()
# Out:
# 'Surat'

# %%
city
# Out:
# 'surat'

# %%
city = city.capitalize()

# %%
city
# Out:
# 'Surat'

# %%
# help()

help(str.capitalize)
# Out:
# Help on method_descriptor:
#
# capitalize(self, /)
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
# casefold() - lower

'LOWER'.casefold()
# Out:
# 'lower'

# %%
# upper()

'upper'.upper()
# Out:
# 'UPPER'

# %%
# title()

'welcome to tops'.title()
# Out:
# 'Welcome To Tops'

# %%
# islower() - returns True if entire string is lowercased else returns False.

'welcome to tops'.islower()
# Out:
# True

# %%
# isupper()

'WELCOME'.isupper()
# Out:
# True

# %%
# istitle()

'Welcome To Tops'.istitle()
# Out:
# True

# %%
# isalnum() - returns True if entire string is only alphabatic or numeric or both else returns False

'hello123'.isalnum()
# Out:
# True

# %%
'hello'.isalnum()
# Out:
# True

# %%
'134665'.isalnum()
# Out:
# True

# %%
'hello 123'.isalnum()
# Out:
# False

# %%
# isalpha()

'hello'.isalpha()
# Out:
# True

# %%
'hello123'.isalpha()
# Out:
# False

# %%
# isnumeric()

'9657'.isnumeric()
# Out:
# True

# %%
# isidentifier()

'hello'.isidentifier()
# Out:
# True

# %%
'hello123'.isidentifier()
# Out:
# True

# %%
'hello_654'.isidentifier()
# Out:
# True

# %%
'he46546llo'.isidentifier()
# Out:
# True

# %%
'hello-world'.isidentifier()
# Out:
# False

# %%
'hello_world'.isidentifier()
# Out:
# True

# %%
'1321hello'.isidentifier()
# Out:
# False

# %%
# isspace() - returns True if entire string has white spaces only else returns False

'hello world'.isspace()
# Out:
# False

# %%
'     '.isspace()
# Out:
# True

# %%
# find(char/word) - returns an index number if given char/word found else returns -1

string = 'welcome to tops'

# %%
string.find('o')
# Out:
# 4

# %%
string.find('x')
# Out:
# -1

# %%
# rfind(char/word) - returns an index number if given char/word found on first occurrance from right side else returns -1

string.rfind('o')
# Out:
# 12

# %%
# index(char/word) - returns an index number if given char/word found else raised an error called ValueError

string.index('o')
# Out:
# 4

# %%
string.index('x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-6fa4791dc117> in <module>()
# ----> 1 string.index('x')
#
# ValueError: substring not found

# %%
# rindex() - returns an index number if given char/word found on first occurrance from right side else raised an error called ValueError

string.rindex('o')
# Out:
# 12

# %%
string.rindex('x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-4a5178cea466> in <module>()
# ----> 1 string.rindex('x')
#
# ValueError: substring not found

# %%
# strip() - remove white spaces from right and left side

'   hello      '.strip()
# Out:
# 'hello'

# %%
# lstrip() - remove white spaces from left side

'      hello     '.lstrip()
# Out:
# 'hello     '

# %%
# rstrip() - remove white spaces from right side

'      hello     '.rstrip()
# Out:
# '      hello'

# %%
'   hell      o   w o  rld  '.strip()
# Out:
# 'hell      o   w o  rld'

# %%
# split(maxsplit=1) - bydefault splits from a white space - returns a list of all words and invdidual chars, each word or char will set in list as an item.
# split(char/word)

string
# Out:
# 'welcome to tops'

# %%
string.split()
# Out:
# ['welcome', 'to', 'tops']

# %%
string.split('o')
# Out:
# ['welc', 'me t', ' t', 'ps']

# %%
string.split('o', 2)
# Out:
# ['welc', 'me t', ' tops']

# %%
# rsplit()

string.rsplit()
# Out:
# ['welcome', 'to', 'tops']

# %%
string.split()
# Out:
# ['welcome', 'to', 'tops']

# %%
string.rsplit(maxsplit=1)
# Out:
# ['welcome to', 'tops']

# %%
string.rsplit('o', 2)
# Out:
# ['welcome t', ' t', 'ps']

# %%
'   hell      o   w o  rld  '.split()
# Out:
# ['hell', 'o', 'w', 'o', 'rld']

# %%
'  d  in   e  sh    '.split()
# Out:
# ['d', 'in', 'e', 'sh']

# %%
# join(sequencial_object)

'*'.join('hello')
# Out:
# 'h*e*l*l*o'

# %%
a = '  d  in   e  sh    '.split()

# %%
a
# Out:
# ['d', 'in', 'e', 'sh']

# %%
'*'.join(a)
# Out:
# 'd*in*e*sh'

# %%
''.join(a)
# Out:
# 'dinesh'

# %%
name = input('enter your name: ')
print(name)
# Out:
# enter your name: d   i ne sh
# d   i ne sh

# %%
name = input('enter your name: ')
name = name.split()
name = ''.join(name)

print(name)
# Out:
# enter your name: d   in  e   sh
# dinesh

# %%
print(*['d', 'in', 'e', 'sh'])
# Out:
# d in e sh

# %%
print('hello', 'world')
# Out:
# hello world

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
'hello\nworld'
# Out:
# 'hello\nworld'

# %%
print('hello\nworld')
# Out:
# hello
# world

# %%
print('hello', 'world', sep="-")
# Out:
# hello-world

# %%
print('hello', 'world', sep="\n")
# Out:
# hello
# world

# %%
print('hello')
print('world')
print('how')
print('are')
print('you')
# Out:
# hello
# world
# how
# are
# you

# %%
print('hello', end=" ")
print('world', end=" ")
print('how', end=" ")
print('are', end=" ")
print('you')
# Out:
# hello world how are you

# %%
# center(width=int, fillchar=" ")

string.center(50)# center(width=int, fillchar=" ")

string.center(50)
# Out:
# '                 welcome to tops                  '

# %%
string.center(50, '*')
# Out:
# '*****************welcome to tops******************'

# %%
# ljust(width)

string.ljust(50)# ljust(width)

string.ljust(50)
# Out:
# 'welcome to tops                                   '

# %%
# rjust(50)

string.rjust(50)# rjust(50)

string.rjust(50)
# Out:
# '                                   welcome to tops'

# %%
# partition(char/word) - returns a tuple which has three items only

string.partition('o')# partition(char/word) - returns a tuple which has three items only

string.partition('o')
# Out:
# ('welc', 'o', 'me to tops')

# %%
string.partition('w')
# Out:
# ('', 'w', 'elcome to tops')

# %%
# rpartition(char/word)

string.rpartition('o')# rpartition(char/word)

string.rpartition('o')
# Out:
# ('welcome to t', 'o', 'ps')

# %%
# swapcase() - toggle the cases

'TiTlE'.swapcase()# swapcase() - toggle the cases

'TiTlE'.swapcase()
# Out:
# 'tItLe'

# %%
# splitlines() - split string from new lines

'hello\nworld'.splitlines()# splitlines() - split string from new lines

'hello\nworld'.splitlines()
# Out:
# ['hello', 'world']

# %%
'''hello
world
how
are
you''''''hello
world
how
are
you'''
# Out:
# 'hello\nworld\nhow\nare\nyouhello\nworld\nhow\nare\nyou'

# %%
'''hello
world
how
are
you'''.splitlines()

# %%
# startswith(char/word) - returns True if string starts with given char/word

string.startswith('w')

# %%
string.startswith('W')

# %%
# endswith(char/word)

string.endswith('s')

# %%
# zfill(int) - zero fill

'hello'.zfill(10)

# %%
digits = 10
roll_num = input('enter your roll number: ')
r = roll_num.zfill(digits)

print(r)

# %%
# replace(old, new, count)

string = 'welcome to python learning center'

# %%
string.replace('python', 'data science')

# %%
string.replace('o', 'X')

# %%
string.replace('o', 'X', 2)

# %%
# format(*args)

string = 'Hello {}! Welcome to {}.'

# %%
string

# %%
print(string)

# %%
string.format('dinesh')

# %%
string.format('tops', 'dinesh')

# %%
# using index number

string = 'Hello {1}! Welcome to {0}.'

# %%
string.format('tops', 'dinesh')

# %%
string = 'Hello {name}! Welcome to {place}.'

# %%
string.format(name='dinesh', place='tops')

# %%
string.format(place='tops', name='dinesh')

# %%
# f-string

string = f'Hello {}! Welcome to {}.'

# %%
name = 'dinesh'
place = 'tops'

string = f'Hello {name}! Welcome to {place}.'

print(string)

# %%
name = 'dinesh'
place = 'tops'

string = f'Hello {name}! Welcome to {place}.'

print(string)

# %%
"Hello _! welcome to tops."
